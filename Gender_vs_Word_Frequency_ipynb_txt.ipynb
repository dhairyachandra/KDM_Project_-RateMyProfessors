# %% [markdown]
# <a href="https://colab.research.google.com/github/dhairyachandra/KDM_Project_-RateMyProfessors/blob/main/Gender_vs_Word_Frequency_ipynb_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scattertext

# %%
import scattertext as st
import spacy
import pandas as pd

# %%
df = pd.read_csv('/content/RateMyProfessor_Sample data.csv')

#Removes unkown genders
df_male_female = df[df['gender'].str.contains(
                'male|female', na=False)]

# %%
nlp = spacy.load('en')

# %%
import nltk
nltk.download('stopwords')

#Establishes stopwords
with open('stopwords.txt', 'r') as f:
    str_f = f.read()
    stopwords_file = set(str_f.split('\n'))
nlp.Defaults.stop_words |= stopwords_file

from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))
nlp.Defaults.stop_words |= stopWords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#            professor_name  ... IsCourseOnline
# 0          Leslie  Looney  ...              0
# 1          Leslie  Looney  ...              0
# 2          Leslie  Looney  ...              0
# 3          Leslie  Looney  ...              0
# 4          Leslie  Looney  ...              0
# ...                   ...  ...            ...
# 19995  Dennis  Richardson  ...              0
# 19996  Dennis  Richardson  ...              0
# 19997  Dennis  Richardson  ...              0
# 19998  Dennis  Richardson  ...              0
# 19999  Dennis  Richardson  ...              0
#
# [20000 rows x 51 columns]

# %%
#Builds corpus (Gender v. Comments), and removes stopwords
corpus = st.CorpusFromPandas(df_male_female, 
                            category_col='gender',
                            text_col='comment',
                            nlp=nlp).build().remove_terms(nlp.Defaults.stop_words, ignore_absences=True)

# %%
#Builds html file
html = st.produce_scattertext_explorer(corpus,
          category='male',
          category_name='Male',
          not_category_name='Female',
          width_in_pixels=1000,
          height_in_pixels=700,
          metadata=df_male_female['professor_name'])
open("Gender-Vs-Word-Frequency.html", 'wb').write(html.encode('utf-8'))
# Out:
# 1628316
